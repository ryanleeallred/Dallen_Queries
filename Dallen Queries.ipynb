# %% [markdown]
# ## Imports & Display Options

# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_columns', 45)

# %% [markdown]
# ## Load Data

# %%
df_20161101 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20161101.csv', sep='|', na_values=['nan', ' ', '  '])
print("Dataset 1 Loaded")
df_20161108 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20161108.csv', sep='|', na_values=['nan', ' ', '  '])
print("Dataset 2 Loaded")
df_20161116 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20161116.csv', sep='|', na_values=['nan', ' ', '  '])
print("Dataset 3 Loaded")
df_20161122 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20161122.csv', sep='|', na_values=['nan', ' ', '  '])
print("Dataset 4 Loaded")
df_20161129 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20161129.csv', sep='|', na_values=['nan', ' ', '  '])
print("Dataset 5 Loaded")
df_20161206 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20161206.csv', sep='|', na_values=['nan', ' ', '  '])
print("Dataset 6 Loaded")
df_20170110 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20170110.csv', sep='|', na_values=['nan', ' ', '  '])
print("Dataset 7 Loaded")
df_20170116 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20170116.csv', sep='|', na_values=['nan', ' ', '  '], low_memory=False)
print("Dataset 8 Loaded")
df_20170117 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20170117.csv', sep='|', na_values=['nan', ' ', '  '])
print("Dataset 9 Loaded")
df_20170124 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20170124.csv', sep='|', na_values=['nan', ' ', '  '])
print("Dataset 10 Loaded")
df_20170131 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20170131.csv', sep='|', na_values=['nan', ' ', '  '])
print("Dataset 11 Loaded")
df_20170207 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20170207.csv', sep='|', na_values=['nan', ' ', '  '], low_memory=False)
print("Dataset 12 Loaded")
df_20170214 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20170214.csv', sep='|', na_values=['nan', ' ', '  '])
print("Dataset 13 Loaded")
df_20170221 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20170221.csv', sep='|', na_values=['nan', ' ', '  '])
print("Dataset 14 Loaded")
df_20170301 =  pd.read_csv('/Users/ryanallred/Desktop/Rx_Claims/Rx_BenefitPlan_20170301.csv', sep='|', na_values=['nan', ' ', '  '], low_memory=False)
print("Dataset 15 Loaded")
# Out:
# Dataset 1 Loaded
# Dataset 2 Loaded
# Dataset 3 Loaded
# Dataset 4 Loaded
# Dataset 5 Loaded
# Dataset 6 Loaded
# /Users/ryanallred/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Dataset 7 Loaded
# Dataset 8 Loaded
# Dataset 9 Loaded
# Dataset 10 Loaded
# Dataset 11 Loaded
# Dataset 12 Loaded
# Dataset 13 Loaded
# Dataset 14 Loaded
# Dataset 15 Loaded

# %%
df = pd.concat([df_20161101, df_20161108, df_20161116, df_20161122, df_20161129,
                                     df_20161206, df_20170110, df_20170116, df_20170117, df_20170124, 
                                     df_20170131, df_20170207, df_20170214, df_20170221, df_20170301])

# %% [markdown]
# ## View Dataframe Shape and Head

# %%
print(df.shape)
df.head()
# Out:
# (4431552, 42)
#   AHFSTherapeuticClassCode         ClaimID ClaimStatus  CoInsurance  \
# 0                 40282000  00005392286554           P          nan
# 1                 28129200  00005394709754           P          nan
# 2                 84920000  00005394709631           P          nan
# 3                 40280800  00005396245992           P          nan
# 4                 28080800  00005396901904           J          nan
#
#    CompoundDrugIndicator  Copay  DAWCode  DateFilled  DaysSupply  Deductible  \
# 0                      1     30        0  2016-10-24          90           0
# 1                      1     10        0  2016-10-25          30           0
# 2                      1     20        0  2016-10-25          30           0
# 3                      1     10        0  2016-10-26          30           0
# 4                      1      0        0  2016-10-27          30           0
#
#    DispensingFee                                      DrugLabelName  \
# ...

# %% [markdown]
# ## Count Missing Values

# %%
# Count Missing Values
df.isnull().sum().sort_values(ascending = False)
# Out:
# PharmacyStreetAddress2      3093678
# PrescriberFirstName          946460
# PharmacyTaxId                412298
# AHFSTherapeuticClassCode     336672
# PharmacyState                309527
# PharmacyCity                 309515
# PharmacyStreetAddress1       309515
# PharmacyZip                  309509
# FormularyStatus              290636
# PresriberLastName            244009
# PharmacyName                 218248
# DispensingFee                168770
# IngredientCost               168394
# ClaimStatus                  163611
# RxNumber                     160890
# PharmacyNPI                  126246
# CoInsurance                  115430
# PharmacyNumber                80214
# UnitMeasure                   57101
# DrugLabelName                 53061
# Quantity                      53054
# Generic                       16365
# CompoundDrugIndicator          8723
# PrescriberID                   4016
# DAWCode                        3640
# MailOrderPharmacy               586
# ...

# %% [markdown]
# # Number of Claims by PBM

# %%
df['PBMVendor'].value_counts()
# Out:
# CVSPAL4000         2764364
# Medco               630260
# MedImpact           574053
# MaxorPlus           160890
# Magellan            102802
# Envision             95176
# RXPreferred          53054
# SouthernScripts      18836
# Welldyne             14211
# Navitus               7504
# Nemop                 5033
# OptumRX               3640
# National              1353
# CanaRX                 376
# Name: PBMVendor, dtype: int64

# %% [markdown]
# ## Number of Claims by NDC Code

# %%
df['NDCCode'].value_counts()
# Out:
# 59310057922    52028
# 55111015810    27974
# 54327099       26288
# 68180051403    24712
# 29300012810    18758
# 68180051503    17990
# 60505082901    16426
# 781261305      16070
# 59762306001    15147
# 53746046605    14591
# 68180051703    13999
# 555901658      12932
# 65862005299    12920
# 68180051303    12749
# 52027303       12055
# 13668001005    11830
# 50111043301    11673
# 10370010150    11519
# 88221905       11181
# 173068220      10960
# 378232105      10762
# 172208380      10607
# 173069600      10268
# 378395277       9970
# 378395177       9960
# 378395077       9907
# 93742698        9742
# 69422030        9633
# 555904358       9489
# 53746010901     9384
#                ...
# 58160082052        1
# 68084062221        1
# 904573651          1
# 63323069404        1
# 13668008830        1
# 51672135008        1
# 68382076405        1
# 62559038001        1
# 51079051820        1
# 66758016013        1
# 60505357901        1
# 55111017005        1
# ...

# %% [markdown]
# ## Replace multiple whitespace with single whitespace in DrugLabelName

# %%
df['DrugLabelName'] = df['DrugLabelName'].astype(str)
df['DrugLabelName'] = df['DrugLabelName'].apply(lambda drug: ' '.join(drug.split()))

# %% [markdown]
# ## Filter out rows where ingredient cost is <= 0

# %%
df = df[df['IngredientCost'] > 0]
print(df.shape)
df.head()
# Out:
# (3703065, 42)
#   AHFSTherapeuticClassCode         ClaimID ClaimStatus  CoInsurance  \
# 0                 40282000  00005392286554           P          nan
# 1                 28129200  00005394709754           P          nan
# 2                 84920000  00005394709631           P          nan
# 3                 40280800  00005396245992           P          nan
# 5                 24240000  00005397740988           J          nan
#
#    CompoundDrugIndicator  Copay  DAWCode  DateFilled  DaysSupply  Deductible  \
# 0                      1     30        0  2016-10-24          90           0
# 1                      1     10        0  2016-10-25          30           0
# 2                      1     20        0  2016-10-25          30           0
# 3                      1     10        0  2016-10-26          30           0
# 5                      1      0        0  2016-10-27          30           0
#
#    DispensingFee        DrugLabelName FillNumber FormularyStatus Generic  \
# ...

# %% [markdown]
# ## Filter out rows where quantity <= 0

# %%
df = df[df['Quantity'] > 0]
print(df.shape)
df.head()
# Out:
# (3639401, 42)
#   AHFSTherapeuticClassCode         ClaimID ClaimStatus  CoInsurance  \
# 0                 40282000  00005392286554           P          nan
# 1                 28129200  00005394709754           P          nan
# 2                 84920000  00005394709631           P          nan
# 3                 40280800  00005396245992           P          nan
# 5                 24240000  00005397740988           J          nan
#
#    CompoundDrugIndicator  Copay  DAWCode  DateFilled  DaysSupply  Deductible  \
# 0                      1     30        0  2016-10-24          90           0
# 1                      1     10        0  2016-10-25          30           0
# 2                      1     20        0  2016-10-25          30           0
# 3                      1     10        0  2016-10-26          30           0
# 5                      1      0        0  2016-10-27          30           0
#
#    DispensingFee        DrugLabelName FillNumber FormularyStatus Generic  \
# ...

# %% [markdown]
# ## Groupby NDC Code
# ## Create Dataframe of the Groupby to get Counts of NDC Codes

# %%
grouped = df.groupby(by='NDCCode', as_index=False).size()
grouped.name = 'count'
grouped = grouped.reset_index()
grouped.head()
# Out:
#      NDCCode  count
# 0       0.00    633
# 1   30001.00      1
# 2 2143301.00      3
# 3 2143380.00    543
# 4 2143401.00      9

# %% [markdown]
# ## Find Average of IngredientCost by NCDCode and add to dataframe

# %%
average_ingredient_cost_list = df.groupby('NDCCode')['IngredientCost'].mean().tolist()
average_ingredient_cost_series = pd.Series(average_ingredient_cost_list)
grouped['AverageIngredientCost'] = average_ingredient_cost_series.values
grouped.head()
# Out:
#      NDCCode  count  AverageIngredientCost
# 0       0.00    633                 867.22
# 1   30001.00      1                   0.84
# 2 2143301.00      3                1516.98
# 3 2143380.00    543                 744.47
# 4 2143401.00      9                 565.72

# %% [markdown]
# ## Find Average of Quantity by NCDCode and add to dataframe

# %%
average_quantity_list = df.groupby('NDCCode')['Quantity'].mean().tolist()
average_quantity_series = pd.Series(average_quantity_list)
grouped['AverageQuantity'] = average_quantity_series.values
grouped.head()
# Out:
#      NDCCode  count  AverageIngredientCost  AverageQuantity
# 0       0.00    633                 867.22           174.11
# 1   30001.00      1                   0.84             1.00
# 2 2143301.00      3                1516.98             4.67
# 3 2143380.00    543                 744.47             2.54
# 4 2143401.00      9                 565.72             2.00

# %% [markdown]
# ## Sort by NDC Code Counts

# %%
sorted = grouped.sort_values(by=['count'], ascending=False)
sorted.head()
# Out:
#              NDCCode  count  AverageIngredientCost  AverageQuantity
# 15220 59310057922.00  42836                  62.03             9.72
# 14459 55111015810.00  22967                  56.34            45.71
# 761      54327099.00  21522                  45.26            19.14
# 19460 68180051403.00  21244                   8.87            42.96
# 19463 68180051503.00  15624                  10.35            44.60

# %% [markdown]
# ## Groupby DrugLabelName and sort to check if NDC Code and DrugLabelName are 1:1

# %%
names = df.groupby(by='DrugLabelName', as_index=False).size()
names.name = 'count'
names = names.reset_index()
names.head()
# Out:
#                DrugLabelName  count
# 0                                 6
# 1    10ML LL SYRN MIS 20GX1"      1
# 2  1ML MEDSAVER SYRINGE/REGU      2
# 3   1ML SYRINGE MIS 28GX1/2"     12
# 4    1ML TB SYRNG MIS 21GX1"      1

# %%
sorted_names = names.sort_values(by=['count'], ascending=False)
sorted_names.head()
# Out:
#               DrugLabelName  count
# 6159             LISINOPRIL  45094
# 8966         PROAIR HFA AER  31305
# 4327  FLUTICASONE SPR 50MCG  27922
# 9848            SIMVASTATIN  27900
# 7929             OMEPRAZOLE  27834

# %% [markdown]
# # DrugLabelNames are not unique to NDCCodes!!!
# ## Get the most common DrugLabelName for a given NDC Code and use that as the DrugLabelName

# %%
drug_labels = []
for row in sorted.iterrows():
    temp_df = df[df.NDCCode == row[1][0]]
    drug_labels.append(temp_df.DrugLabelName.value_counts().index.tolist()[0])

print(drug_labels)

# %%
drug_label_list = pd.Series(drug_labels)
sorted['DrugLabel'] = drug_label_list.values

# %%
sorted.head()

# %% [markdown]
# ## Export to CSV Sorted list of NDC Code counts with Drug Label Names

# %%
sorted.to_csv('claims_by_NDCCode.csv', index=False)
